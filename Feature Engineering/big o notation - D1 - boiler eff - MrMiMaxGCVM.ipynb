# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

import os
import psutil # Pastikan sudah install: pip install psutil

# Import dasar untuk SklearnWrapper
from sklearn.base import BaseEstimator, RegressorMixin

# Import model-model yang digunakan dalam base_estimators
from sklearn.ensemble import (StackingRegressor, RandomForestRegressor, 
                              ExtraTreesRegressor, GradientBoostingRegressor, 
                              AdaBoostRegressor)
from sklearn.linear_model import RidgeCV, Lasso
from sklearn.svm import SVR

# Import model pihak ketiga (pastikan sudah install: pip install xgboost lightgbm catboost)
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor

# %%
# 1. LOAD DATA
df = pd.read_excel('Dataset 1 (ops).xlsx')
X = df.drop(columns=['Boiler Eff (%)','NPHR (Kcal/Kwh)'])
y = df['Boiler Eff (%)']

# %%
df
# Out:
#      Main steam flow (t/h)  Main steam temperature (boiler side) (℃)  \
# 0               983.364461                                568.098974
# 1               903.312848                                568.023808
# 2               903.734408                                568.650337
# 3               877.767639                                568.262788
# 4               921.238833                                568.102547
# ..                     ...                                       ...
# 544             963.383357                                567.188810
# 545             890.941643                                567.664945
# 546             882.807854                                567.590635
# 547             917.612111                                567.520828
# 548             945.475950                                567.872590
#
#      Main steam pressure (boiler side) (Mpa)  \
# 0                                  15.970471
# 1                                  14.907765
# 2                                  14.869165
# 3                                  14.422768
# 4                                  15.204717
# ..                                       ...
# 544                                15.563528
# 545                                14.386963
# 546                                14.158093
# 547                                14.621877
# 548                                15.210988
#
#      Reheat steam temperature (boiler side) (℃)  \
# 0                                    566.719831
# 1                                    563.985723
# 2                                    565.670929
# 3                                    564.237198
# 4                                    565.474856
# ..                                          ...
# 544                                  564.490362
# 545                                  565.543734
# 546                                  566.011767
# 547                                  566.072634
# 548                                  565.812243
#
#      Superheater desuperheating water flow (t/h)  \
# 0                                     128.135595
# 1                                     119.628420
# 2                                     110.785154
# 3                                      97.307475
# 4                                      93.665703
# ..                                           ...
# 544                                    89.382077
# 545                                    83.488775
# 546                                   102.147880
# 547                                   106.958025
# 548                                   100.850509
#
#      Reheater desuperheating water flow (t/h)  Feedwater temperature (℃)  \
# 0                                    0.935145                 258.021498
# 1                                    1.944743                 253.733859
# 2                                    1.437433                 253.613525
# 3                                    0.983420                 252.217335
# 4                                    0.798093                 254.271976
# ..                                        ...                        ...
# 544                                  3.987283                 257.473513
# 545                                  1.646984                 253.524998
# 546                                  3.174934                 252.915498
# 547                                  6.522704                 254.775243
# 548                                  4.145483                 256.468134
#
#      Feedwater flow (t/h)  Flue gas temperature (℃)  Boiler oxygen level (%)  \
# 0             1035.752935                130.708067                 3.828501
# 1              964.867360                129.803971                 3.659717
# 2              959.486415                127.860081                 3.561764
# 3              938.427597                129.812856                 3.905170
# 4              974.631602                130.218360                 3.879849
# ..                    ...                       ...                      ...
# 544            970.169352                124.009406                 3.292357
# 545            895.883235                123.268547                 3.498842
# 546            886.779790                124.640201                 3.468605
# 547            915.165001                127.187321                 3.320881
# 548            947.311071                125.778090                 3.481395
#
#      ...  Coal Flow (t/h)  NPHR (Kcal/Kwh)  Gross Load (MW)  Nett Load (MW)  \
# 0    ...           192.41      2607.270106           344.56          323.93
# 1    ...           181.37      2687.121676           316.02          296.27
# 2    ...           178.47      2663.032090           314.22          294.17
# 3    ...           172.09      2651.943177           304.68          284.84
# 4    ...           181.74      2651.524408           320.94          300.86
# ..   ...              ...              ...              ...             ...
# 544  ...           172.99      2362.587163           329.71          310.26
# 545  ...           164.77      2421.984297           307.55          288.27
# 546  ...           169.38      2522.739965           303.77          284.50
# 547  ...           179.69      2584.543200           314.09          294.60
# 548  ...           179.24      2498.107511           323.72          304.03
#
#      HHV (Kcal/Kg)  Pressure HRH  Temperature HRH  Spray reheat pressure  \
# 0      4389.444444          2.29           566.36                   5.50
# 1      4389.444444          2.10           565.00                   5.11
# 2      4389.444444          2.09           565.63                   5.08
# 3      4389.444444          2.03           564.09                   4.92
# 4      4389.444444          2.13           565.75                   5.23
# ..             ...           ...              ...                    ...
# 544    4237.333333          2.22           565.60                   5.37
# 545    4237.333333          2.08           565.79                   4.96
# 546    4237.333333          2.05           565.84                   4.84
# 547    4237.333333          2.12           566.30                   5.00
# 548    4237.333333          2.19           565.82                   5.24
#
#      Spray reheat temperature  Boiler Eff (%)
# 0                      159.91       77.915748
# 1                      149.95       76.294873
# 2                      149.38       77.886219
# 3                      141.10       78.367624
# 4                      148.33       77.856369
# ..                        ...             ...
# 544                    155.64       89.855113
# 545                    150.91       88.052730
# 546                    149.64       85.018900
# 547                    153.37       83.295960
# 548                    154.96       85.551217
#
# [549 rows x 35 columns]

# %%
# 2. SETUP EKSPERIMEN
sample_sizes = np.linspace(0.1, 1.0, 10) 
n_records = []
training_times = []
inference_times = []

# %%
# --- COMPATIBILITY WRAPPER (FIXED for sklearn 1.8.0 Tags system) ---
class SklearnWrapper(BaseEstimator, RegressorMixin):
    """Wrapper untuk kompatibilitas dengan sklearn StackingRegressor"""
    def __init__(self, model):
        self.model = model
    
    def fit(self, X, y, **fit_params):
        self.model.fit(X, y, **fit_params)
        return self
    
    def predict(self, X):
        return self.model.predict(X)
    
    def get_params(self, deep=True):
        return {"model": self.model}
    
    def set_params(self, **params):
        if "model" in params:
            self.model = params["model"]
        return self
    
    # Implement __sklearn_tags__ for proper regressor detection in sklearn 1.8.0+
    def __sklearn_tags__(self):
        from sklearn.utils._tags import Tags, RegressorTags, TargetTags, InputTags
        tags = Tags(
            estimator_type="regressor",
            target_tags=TargetTags(
                required=False,
                one_d_labels=False,
                two_d_labels=False,
                positive_only=False,
                multi_output=False,
                single_output=True
            ),
            regressor_tags=RegressorTags(),
            input_tags=InputTags()
        )
        return tags


# ==========================================
# 3. LOOPING UNTUK MENGUKUR WAKTU
# ==========================================
print(f"{'N':<8} | {'Train Time (s)':<15} | {'Inf Time (s)':<15}")
print("-" * 45)

# 3. LOOPING PENGUKURAN
for prop in sample_sizes:
    n = int(len(df) * prop)
    X_subset = X.iloc[:n]
    y_subset = y.iloc[:n]
    n_records.append(n)

    # ----------------------------------------------------
    # SETUP STACKING REGRESSOR
    # ----------------------------------------------------
    # 1. Definisikan Base Models (Sesuaikan dengan model di notebook Anda)
    # Contoh di bawah ini menggunakan Random Forest dan XGBoost
    base_estimators = [
   ('xgb', SklearnWrapper(xgb.XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=5, random_state=42))),
    ('cat', SklearnWrapper(CatBoostRegressor(iterations=500, learning_rate=0.05, depth=6, verbose=0, random_state=42))),
    ('lgbm', SklearnWrapper(lgb.LGBMRegressor(n_estimators=500, learning_rate=0.05, verbosity=-1, random_state=42))),
    ('rf', RandomForestRegressor(n_estimators=300, max_depth=10, random_state=42)),
    ('et', ExtraTreesRegressor(n_estimators=300, random_state=42)),
    ('gb', GradientBoostingRegressor(n_estimators=300, random_state=42)),
    ('ada', AdaBoostRegressor(n_estimators=100, random_state=42)),
    ('svr', SklearnWrapper(SVR(C=1.0, epsilon=0.1))),
    ('lasso', Lasso(alpha=0.01))
    ]
    
    # 2. Definisikan Final Estimator (Meta-model)
    final_estimator = RidgeCV()
    
    # 3. Gabungkan ke dalam StackingRegressor
    model = StackingRegressor(
        estimators=base_estimators,
        final_estimator=final_estimator,
        cv=5 # Menggunakan 5-fold cross validation saat melatih meta-model
    )
    # ----------------------------------------------------
    
    # --- PENGUKURAN TRAINING ---
    start_train = time.time()
    model.fit(X_subset, y_subset)
    end_train = time.time()
    training_times.append(end_train - start_train)

    # --- PENGUKURAN INFERENCE (DETEKSI) ---
    start_inf = time.time()
    model.predict(X_subset)
    end_inf = time.time()
    inference_times.append(end_inf - start_inf)

    print(f"{n:<8} | {training_times[-1]:<15.4f} | {inference_times[-1]:<15.4f}")
# Out:
# N        | Train Time (s)  | Inf Time (s)
# ---------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.180e+00, tolerance: 2.651e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.035e+00, tolerance: 2.245e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.526e-01, tolerance: 2.440e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.604e-01, tolerance: 2.189e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+00, tolerance: 2.530e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.626e-01, tolerance: 8.137e-03
#   model = cd_fast.enet_coordinate_descent(
# 54       | 7.4378          | 0.0307
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.260e+00, tolerance: 8.752e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.787e+00, tolerance: 6.887e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.100e+00, tolerance: 7.420e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.134e+00, tolerance: 6.429e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.847e+00, tolerance: 8.163e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.593e+00, tolerance: 4.970e-02
#   model = cd_fast.enet_coordinate_descent(
# 109      | 10.5689         | 0.0468
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+01, tolerance: 3.249e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.926e+00, tolerance: 2.146e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.021e+01, tolerance: 3.045e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.889e+00, tolerance: 2.812e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.548e+00, tolerance: 2.446e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.802e+00, tolerance: 1.919e-01
#   model = cd_fast.enet_coordinate_descent(
# 164      | 21.5822         | 0.0627
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.309e+01, tolerance: 4.834e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.070e+00, tolerance: 3.106e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+01, tolerance: 4.256e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.099e+01, tolerance: 4.190e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.120e+00, tolerance: 3.427e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.176e+01, tolerance: 3.671e-01
#   model = cd_fast.enet_coordinate_descent(
# 219      | 22.3418         | 0.0506
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.176e+01, tolerance: 5.086e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.272e+01, tolerance: 3.376e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e+01, tolerance: 4.383e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.705e+00, tolerance: 3.525e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.214e+01, tolerance: 3.550e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.293e+01, tolerance: 4.835e-01
#   model = cd_fast.enet_coordinate_descent(
# 274      | 26.4560         | 0.0663
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.198e+01, tolerance: 5.289e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.026e+01, tolerance: 3.673e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.157e+01, tolerance: 4.275e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.211e-01, tolerance: 2.486e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.204e+01, tolerance: 5.100e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.307e+01, tolerance: 4.944e-01
#   model = cd_fast.enet_coordinate_descent(
# 329      | 33.9073         | 0.0883
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.399e+01, tolerance: 5.777e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.695e+00, tolerance: 3.839e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.274e+01, tolerance: 4.280e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.403e+00, tolerance: 3.905e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.454e+01, tolerance: 5.364e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.162e+01, tolerance: 5.261e-01
#   model = cd_fast.enet_coordinate_descent(
# 384      | 37.7919         | 0.0930
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.474e+01, tolerance: 6.222e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.849e+00, tolerance: 3.909e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.350e+00, tolerance: 4.255e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.412e+01, tolerance: 4.983e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.722e+01, tolerance: 5.828e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e+01, tolerance: 5.295e-01
#   model = cd_fast.enet_coordinate_descent(
# 439      | 40.1099         | 0.1029
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+01, tolerance: 6.453e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.562e+00, tolerance: 3.855e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.025e+00, tolerance: 3.486e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.216e+01, tolerance: 5.905e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.564e+01, tolerance: 5.727e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.349e+01, tolerance: 5.959e-01
#   model = cd_fast.enet_coordinate_descent(
# 494      | 43.7662         | 0.1258
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.101e+01, tolerance: 6.831e-01
#   model = cd_fast.enet_coordinate_descent(
# 549      | 52.3019         | 0.1566
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e+01, tolerance: 4.060e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.765e+00, tolerance: 4.129e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.517e+01, tolerance: 6.268e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.105e+01, tolerance: 5.961e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.474e+01, tolerance: 6.222e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
# 4. VISUALISASI PERBANDINGAN BIG O
plt.figure(figsize=(14, 6))

# Subplot 1: Training
plt.subplot(1, 2, 1)
plt.plot(n_records, training_times, 'bo-', label='Actual Training (Empirical)')
train_linear = [training_times[-1] * (n / n_records[-1]) for n in n_records]
plt.plot(n_records, train_linear, 'r--', label='Reference O(N)')
plt.title('Big O: Training Process', fontweight='bold')
plt.xlabel('Data Size (N)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.grid(True, alpha=0.3)

# Subplot 2: Inference
plt.subplot(1, 2, 2)
plt.plot(n_records, inference_times, 'go-', label='Actual Inference (Empirical)')
inf_linear = [inference_times[-1] * (n / n_records[-1]) for n in n_records]
plt.plot(n_records, inf_linear, 'r--', label='Reference O(N)')
plt.title('Big O: Inference Process', fontweight='bold')
plt.xlabel('Data Size (N)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
